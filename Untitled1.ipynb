# %%
import pandas as pd
import matplotlib.pyplot as plt

# Example: grouping sales by month-end
bike_monthly = (
    bike.groupby(pd.Grouper(key="order_date", freq="ME"))["amount"]
    .sum()
    .reset_index()
)

# Save to CSV
bike_monthly.to_csv("bicycle_monthly_trend.csv", index=False)
print("Saved monthly trend to bicycle_monthly_trend.csv")

# Plot
plt.figure(figsize=(10, 5))
plt.plot(bike_monthly["order_date"], bike_monthly["amount"], marker="o")
plt.title("Monthly Bicycle Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales Amount")
plt.grid(True)
plt.savefig("bicycle_trend.png")
print("Chart saved to bicycle_trend.png")
plt.show()
# Out:
# Saved monthly trend to bicycle_monthly_trend.csv
# Chart saved to bicycle_trend.png
